# %% [markdown]
# # 1) Import PyNews Library

# %%
from PyNews import *

# %% [markdown]
# # 2) Instantiate PyNews Object

# %%
py = PyNews(key = "4cbdb93514mshc51c9a14a6f8a31p1ec473jsn00c169be7493")

# %% [markdown]
# # 3) Enter Ticker and Number of Articles

# %%
news = py.company_news('aapl', 10)

# %% [markdown]
# #### *View results as a DataFrame*

# %%
news.results
# Out:
#                                                                  title  \
# date
# 2021-01-18 13:18:00         China risk to tech sector expected to fade
# 2021-01-16 18:54:00  Tesla is the only megacap with leverage headin...
# 2021-01-15 18:24:00  Apple roundup: Re-closing some stores, plannin...
# 2021-01-15 12:37:00  Spotify now -6.6% amid report Apple considers ...
# 2021-01-15 05:45:00  Xiaomi plunges 10% as U.S. adds smartphone gia...
# 2021-01-14 19:28:00  Barclays edges more positive on IT hardware - ...
# 2021-01-13 13:33:00  Alibaba and Foxconn the latest to charge into ...
# 2021-01-13 08:43:00  Apple and Canoo (GOEV) discussed possible deal...
# 2021-01-13 06:55:00        Apple iPhones demand starts off 2021 strong
# 2021-01-12 15:31:00  Tesla pulled an Apple move in self-driving, le...
#
#                                                                   text    neg  \
# date
# 2021-01-18 13:18:00   Wedbush Securities predicts the tech sector w...  0.025
# ...

# %% [markdown]
# #### *Get word frequencies*

# %%
vocab = news.get_vectorizer()

# %%
vocab
# Out:
#          word     count
# 99      apple  1.012773
# 511    nasdaq  0.818508
# 521       new  0.631342
# 784     tesla  0.459109
# 191   company  0.441496
# ..        ...       ...
# 310        fb  0.019673
# 526    normal  0.019673
# 525  nikolaos  0.019673
# 313       feb  0.019673
# 0          06  0.019673
#
# [875 rows x 2 columns]

# %% [markdown]
# #### *Plot word frequencies*

# %%
news.plot_vocab(vocab, 15)

# %% [markdown]
# #### *View articles and sentiment scores*

# %%
news.print_news()
# Out:
# TIME: 2021-01-18 13:18:00
# TITLE: China risk to tech sector expected to fade
# SENTIMENTS (positive, neutral, negative): 0.119, 0.856, 0.025
#
# START TEXT
#
# ...
